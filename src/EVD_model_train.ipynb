# %%
# Installing required libraries
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.1/871.1 kB 23.7 MB/s eta 0:00:00
# ...

# %%
# Library Import and GPU Check
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.82 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.8/78.2 GB disk)

# %%
# Mount GDrive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Initiate Model Training
# !yolo task=detect mode=train model=yolov8s.pt data=/content/drive/MyDrive/SIH-2024/src/data/EVD_model/data.yaml epochs=100 batch=10 project=models/EVD_model/content/drive/MyDrive/SIH-2024/src/models/EVD_model
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 222MB/s]
# Ultralytics YOLOv8.2.82 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Model Sample Run
# !yolo task=detect mode=predict model=/content/models/EVD_model/content/drive/MyDrive/SIH-2024/src/models/EVD_model/train/weights/best.pt conf=0.5 source=/content/drive/MyDrive/SIH-2024/src/data/EVD_model/images/val/18.jpg
# Out:
# Ultralytics YOLOv8.2.82 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /content/drive/MyDrive/SIH-2024/src/data/EVD_model/images/val/18.jpg: 640x640 1 ambulance, 16.3ms
# Speed: 5.2ms preprocess, 16.3ms inference, 649.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# Model Finetuning

from Ultralyitcs import YOLO
yolo = YOLO("models/EVD_model/weights/best.pt")
yolo.train(data='',epochs=)
valid_results = yolo.val()
print(valid_results)
